# %% [markdown]
# # Lab | LangChain Med
#
# ## Objectives
#
# - continue on with lesson 2' example, use different datasets to test what we did in class. Some datasets are suggested in the notebook but feel free to scout other datasets on HuggingFace or Kaggle.
# - Find another model on Hugging Face and compare it.
# - Modify the prompt to fit your selected dataset.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load the Dataset
# As you can see the notebook is ready to work with three different Datasets. Just uncomment the lines of the Dataset you want to use.
#
# I selected Datasets with News. Two of them have just a brief decription of the news, but the other contains the full text.
#
# As we are working in a free and limited space, I limited the number of news to use with the variable MAX_NEWS. Feel free to pull more if you have memory available.
#
# The name of the field containing the text of the new is stored in the variable *DOCUMENT* and the metadata in *TOPIC*

# %%
# news = pd.read_csv('/content/labelled_newscatcher_dataset.csv', sep=';')
# MAX_NEWS = 1000
# DOCUMENT="title"
# TOPIC="topic"

news = pd.read_csv('bbc_news.csv')
MAX_NEWS = 1000
DOCUMENT="description"
TOPIC="title"

#news = pd.read_csv('/kaggle/input/mit-ai-news-published-till-2023/articles.csv')
#MAX_NEWS = 100
#DOCUMENT="Article Body"
#TOPIC="Article Header"

#news = "PICK A DATASET" #Ideally pick one from the commented ones above

# %% [markdown]
# ChromaDB requires that the data has a unique identifier. We can make it with this statement, which will create a new column called **Id**.

# %%
news
# Out:
#                                                    title  \
# 0      Ukraine: Angry Zelensky vows to punish Russian...
# 1      War in Ukraine: Taking cover in a town under a...
# 2             Ukraine war 'catastrophic for global food'
# 3      Manchester Arena bombing: Saffie Roussos's par...
# 4      Ukraine conflict: Oil price soars to highest l...
# ...                                                  ...
# 42110           Highlights: Wales make history in Dublin
# 42111  Gang jailed over £200m of cocaine in banana boxes
# 42112   Scottish Budget presents huge challenges for SNP
# 42113  Celebrations as Wales make history qualifying ...
# 42114  School tells Muslim girls it’s ‘not safe’ for ...
#
#                              pubDate  \
# 0      Mon, 07 Mar 2022 08:01:56 GMT
# 1      Sun, 06 Mar 2022 22:49:58 GMT
# 2      Mon, 07 Mar 2022 00:14:42 GMT
# 3      Mon, 07 Mar 2022 00:05:40 GMT
# 4      Mon, 07 Mar 2022 08:15:53 GMT
# ...                              ...
# 42110  Tue, 03 Dec 2024 23:07:27 GMT
# 42111  Tue, 03 Dec 2024 17:48:54 GMT
# 42112  Tue, 03 Dec 2024 23:00:17 GMT
# 42113  Wed, 04 Dec 2024 00:05:52 GMT
# 42114  Wed, 04 Dec 2024 00:03:58 GMT
#
#                                                     guid  \
# 0       https://www.bbc.co.uk/news/world-europe-60638042
# 1       https://www.bbc.co.uk/news/world-europe-60641873
# 2           https://www.bbc.co.uk/news/business-60623941
# 3                 https://www.bbc.co.uk/news/uk-60579079
# 4           https://www.bbc.co.uk/news/business-60642786
# ...                                                  ...
# 42110  https://www.bbc.com/sport/football/videos/ckg1...
# 42111   https://www.bbc.com/news/articles/c3e8pvg284no#9
# 42112   https://www.bbc.com/news/articles/ckg1m1j2grpo#9
# 42113   https://www.bbc.com/news/articles/c791nq8nl73o#9
# 42114   https://www.bbc.com/news/articles/cx2wk0k4597o#9
#
#                                                     link  \
# 0      https://www.bbc.co.uk/news/world-europe-606380...
# 1      https://www.bbc.co.uk/news/world-europe-606418...
# 2      https://www.bbc.co.uk/news/business-60623941?a...
# 3      https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4      https://www.bbc.co.uk/news/business-60642786?a...
# ...                                                  ...
# 42110  https://www.bbc.com/sport/football/videos/ckg1...
# 42111     https://www.bbc.com/news/articles/c3e8pvg284no
# 42112     https://www.bbc.com/news/articles/ckg1m1j2grpo
# 42113     https://www.bbc.com/news/articles/c791nq8nl73o
# 42114     https://www.bbc.com/news/articles/cx2wk0k4597o
#
#                                              description
# 0      The Ukrainian president says the country will ...
# 1      Jeremy Bowen was on the frontline in Irpin, as...
# 2      One of the world's biggest fertiliser firms sa...
# 3      The parents of the Manchester Arena bombing's ...
# 4      Consumers are feeling the impact of higher ene...
# ...                                                  ...
# 42110  Watch highlights as Wales win 2-1 in Dublin fo...
# 42111  More than two tonnes of the Class A drug was s...
# 42112  Finance Secretary Shona Robison is preparing t...
# 42113  Wales defeated the Republic of Ireland 2-1 mak...
# 42114  Three children have not been back to the Belfa...
#
# [42115 rows x 5 columns]

# %%
news["id"] = news.index
news.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# 1  https://www.bbc.co.uk/news/world-europe-606418...
# 2  https://www.bbc.co.uk/news/business-60623941?a...
# 3  https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4  https://www.bbc.co.uk/news/business-60642786?a...
#
#                                          description  id
# 0  The Ukrainian president says the country will ...   0
# 1  Jeremy Bowen was on the frontline in Irpin, as...   1
# 2  One of the world's biggest fertiliser firms sa...   2
# 3  The parents of the Manchester Arena bombing's ...   3
# 4  Consumers are feeling the impact of higher ene...   4

# %%
#Because it is just a course we select a small portion of News.
subset_news = news.head(MAX_NEWS)

# %% [markdown]
# ## Import and configure the Vector Database
# I'm going to use ChromaDB, the most popular OpenSource embedding Database.
#
# First we need to import ChromaDB, and after that import the **Settings** class from **chromadb.config** module. This class allows us to change the setting for the ChromaDB system, and customize its behavior.

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (1.5.9)
# Requirement already satisfied: build>=1.0.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.47.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (2.4.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: certifi in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.14)
# Requirement already satisfied: h11>=0.16 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.33.1)
# Requirement already satisfied: requests-oauthlib in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (1.15.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: click>=8.2.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)

# %%
import chromadb
from chromadb.config import Settings

# %% [markdown]
# Now we need to create the settings object calling the **Settings** function imported previously. We store the object in the variable **settings_chroma**.
#
# Is necessary to inform two parameters
# * chroma_db_impl. Here we specify the database implementation and the format how store the data. I choose ***duckdb***, because his high-performace. It operate primarly in memory. And is fully compatible with SQL. The store format ***parquet*** is good for tabular data. With good compression rates and performance.
#
# * persist_directory: It just contains the directory where the data will be stored. Is possible work without a directory and the data will be stored in memory without persistece, but Kaggle dosn't support that.

# %%
persist_directory = "./chroma_db"
chroma_client = chromadb.PersistentClient(path=persist_directory)

# %% [markdown]
# ## Filling and Querying the ChromaDB Database
# The Data in ChromaDB is stored in collections. If the collection exist we need to delete it.
#
# In the next lines, we are creating the collection by calling the ***create_collection*** function in the ***chroma_client*** created above.

# %%
collection_name = "news_collection"
if len(chroma_client.list_collections()) > 0 and collection_name in [chroma_client.list_collections()[0].name]:
        chroma_client.delete_collection(name=collection_name)

collection = chroma_client.create_collection(name=collection_name)

# %% [markdown]
# It's time to add the data to the collection. Using the function ***add*** we need to inform, at least ***documents***, ***metadatas*** and ***ids***.
# * In the **document** we store the big text, it's a different column in each Dataset.
# * In **metadatas**, we can informa a list of topics.
# * In **id** we need to inform an unique identificator for each row. It MUST be unique! I'm creating the ID using the range of MAX_NEWS.

# %%
collection.add(
    documents=subset_news[DOCUMENT].tolist(),
    metadatas=[{TOPIC: topic} for topic in subset_news[TOPIC].tolist()],
    ids=[f"id{x}" for x in range(MAX_NEWS)],
)

# %%
results = collection.query(query_texts=["laptop"], n_results=10 )

print(results)
# Out:
# {'ids': [['id775', 'id707', 'id310', 'id587', 'id444', 'id751', 'id701', 'id862', 'id191', 'id740']], 'embeddings': None, 'documents': [['Photography student Thorsten Mjölnir captures the way students decorate their laptops.', 'Why sales of very basic mobile phones, without apps and internet connection, are increasing.', "What do you do when your collection of millions of books keeps growing but your bookshelves don't?", 'The developers of a powerful mini aircraft hope it will be used by the armed forces.', 'How tech is helping young families and couples regain their busy social lives after Covid.', 'Watch as Lee Zii Jia of Malaysia records a speed of 372km/h on his backhand point against Lakshya Sen of India in the All England Badminton Championships.', 'The Royal Mint has found a way to turn old circuit boards from phones, computers and TVs into gold.', 'A van was reportedly hijacked and driven to the venue, and a controlled explosion has since been carried out.', 'The Ukrainian president reveals his location in Kyiv in a new video shared on social media.', 'The Royal Mint has found a way to turn old circuit boards from phones, computers and televisions into gold.']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'title': 'Laptop art: From Vans to Harry Styles'}, {'title': "Not smart but clever? The return of 'dumbphones'"}, {'title': 'Building a bigger home for the British Library collection'}, {'title': 'How a jetpack design helped create a flying motorbike'}, {'title': 'The popular apps aiming to tame the chaos of family life'}, {'title': "All England Badminton Championships: Malaysia's Lee Zii Jia records 372km/h backhand"}, {'title': 'E-waste: Royal Mint wants to turn your old phone into gold'}, {'title': "Simon Coveney's visit to Belfast interrupted by security alert"}, {'title': 'War in Ukraine: President Zelensky posts video from office in Kyiv'}, {'title': 'E-waste: Royal Mint wants to turn your old phone into gold'}]], 'distances': [[1.1066491603851318, 1.6309349536895752, 1.6354165077209473, 1.651792287826538, 1.6552249193191528, 1.6666066646575928, 1.668237328529358, 1.6726524829864502, 1.679142713546753, 1.6888481378555298]]}

# %% [markdown]
# ## Vector MAP

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
getado = collection.get(ids="id141",
                       include=["documents", "embeddings"])

# %%
word_vectors = getado["embeddings"]
word_list = getado["documents"]
#word_vectors

# %% [markdown]
# Once we have our information inside the Database we can query It, and ask for data that matches our needs. The search is done inside the content of the document, and it dosn't look for the exact word, or phrase. The results will be based on the similarity between the search terms and the content of documents.
#
# The metadata is not used in the search, but they can be utilized for filtering or refining the results after the initial search.

# %% [markdown]
# ## Loading the model and creating the prompt
# TRANSFORMERS!!
# Time to use the library **transformers**, the most famous library from [hugging face](https://huggingface.co/) for working with language models.
#
# We are importing:
# * **Autotokenizer**: It is a utility class for tokenizing text inputs that are compatible with various pre-trained language models.
# * **AutoModelForCasualLLM**: it provides an interface to pre-trained language models specifically designed for language generation tasks using causal language modeling (e.g., GPT models), or the model used in this notebook ***databricks/dolly-v2-3b***.
# * **pipeline**: provides a simple interface for performing various natural language processing (NLP) tasks, such as text generation (our case) or text classification.
#
# Please, feel free to test [different Models](https://huggingface.co/models?pipeline_tag=text-generation&sort=trending), you need to search for NLP models trained for text-generation. My recomendation is choose "small" models, or we will run out of memory in kaggle.

# %%
# Update transformers and huggingface_hub libraries to ensure compatibility with Hugging Face models
# !pip install --upgrade transformers huggingface_hub

from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "gpt2"    # Dolly-v2 was originally recommended by Databricks, but it could not be loaded in this environment due to availability or compatibility issues, so GPT-2 is used as an alternative.

# It's good practice to add `trust_remote_code=True` when loading models that might have custom code
# or if experiencing issues, although not strictly required for all models.
# For Dolly-v2 models, `trust_remote_code=True` is often recommended.
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
lm_model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# Requirement already satisfied: transformers in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (5.8.1)
# Requirement already satisfied: huggingface_hub in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (1.15.0)
# Requirement already satisfied: numpy>=1.17 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface_hub) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.14)
# Requirement already satisfied: h11>=0.16 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer->transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/chongharnzhin/Documents/Personal/AI/Bootcamp/W7/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 7630.88it/s]

# %% [markdown]
# The next step is to initialize the pipeline using the objects created above.
#
# The model's response is limited to 256 tokens, for this project I'm not interested in a longer response, but it can easily be extended to whatever length you want.
#
# Setting ***device_map*** to ***auto*** we are instructing the model to automaticaly select the most appropiate device: CPU or GPU for processing the text generation.

# %%
pipe = pipeline(
    "text-generation",
    model=lm_model,
    tokenizer=tokenizer,
    max_new_tokens=256,
    device_map="auto",
)

# %% [markdown]
# ## Creating the extended prompt
# To create the prompt we use the result from query the Vector Database  and the sentence introduced by the user.
#
# The prompt have two parts, the **relevant context** that is the information recovered from the database and the **user's question**.
#
# We only need to join the two parts together to create the prompt that we are going to send to the model.
#
# You can limit the lenght of the context passed to the model, because we can get some Memory problems with one of the datasets that contains a realy large text in the document part.

# %%
question = "Can I buy a Toshiba laptop?"
context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
#context = context[0:5120]
prompt_template = f"""
Relevant context:
{context}

Question:
{question}

Answer:
"""
prompt_template
# Out:
# "\nRelevant context:\n#Photography student Thorsten Mjölnir captures the way students decorate their laptops. #Why sales of very basic mobile phones, without apps and internet connection, are increasing. #What do you do when your collection of millions of books keeps growing but your bookshelves don't? #The developers of a powerful mini aircraft hope it will be used by the armed forces. #How tech is helping young families and couples regain their busy social lives after Covid. #Watch as Lee Zii Jia of Malaysia records a speed of 372km/h on his backhand point against Lakshya Sen of India in the All England Badminton Championships. #The Royal Mint has found a way to turn old circuit boards from phones, computers and TVs into gold. #A van was reportedly hijacked and driven to the venue, and a controlled explosion has since been carried out. #The Ukrainian president reveals his location in Kyiv in a new video shared on social media. #The Royal Mint has found a way to turn old circuit boards from phones, computers and televisions into gold.\n\nQuestion:\nCan I buy a Toshiba laptop?\n\nAnswer:\n"

# %% [markdown]
# Now all that remains is to send the prompt to the model and wait for its response!

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Relevant context:
# #Photography student Thorsten Mjölnir captures the way students decorate their laptops. #Why sales of very basic mobile phones, without apps and internet connection, are increasing. #What do you do when your collection of millions of books keeps growing but your bookshelves don't? #The developers of a powerful mini aircraft hope it will be used by the armed forces. #How tech is helping young families and couples regain their busy social lives after Covid. #Watch as Lee Zii Jia of Malaysia records a speed of 372km/h on his backhand point against Lakshya Sen of India in the All England Badminton Championships. #The Royal Mint has found a way to turn old circuit boards from phones, computers and TVs into gold. #A van was reportedly hijacked and driven to the venue, and a controlled explosion has since been carried out. #The Ukrainian president reveals his location in Kyiv in a new video shared on social media. #The Royal Mint has found a way to turn old circuit boards from phones, computers and televisions into gold.
#
# Question:
# Can I buy a Toshiba laptop?
#
# Answer:
#
# The Japanese company has announced a new form factor. The latest model is the Kobo, which is priced at $249.99, with the Kobo keyboard and mouse as standard.
#
# And for those who don't know, a device can come with an additional 3.5kg of storage, which can be used for up to 12 hours at a time. A USB drive can be used for up to 3 years. It is possible to buy a Toshiba laptop with a USB-C port; we've already seen some devices with USB-C ports, but there are so many features we couldn't find here.
#
# What about the idea of sending a message via Wi-Fi or Bluetooth?
#
# Answer:
#
# The idea is that you can send a message via Wi-Fi or Bluetooth. But, it's a bit of a complicated idea to use.
#
# What about sending a message via a phone?
#
# Answer:
#
# The idea is that you can send a message via a phone.
#
# What about sending a message via a video link to an e-mail address?
#
# Answer:
#
# The idea is that you can send a message via video link.
#
# What about sending a message via a mobile
